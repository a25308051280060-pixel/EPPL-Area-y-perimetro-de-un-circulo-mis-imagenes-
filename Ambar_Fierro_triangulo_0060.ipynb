# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280060-pixel/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes-/blob/main/Ambar_Fierro_triangulo_0060.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ambar Fierro NL = 19 FEcha 25/mar/2026 ❤
# ---
# ## calcular area de un triangulo
# ---
# ![Logo de Markdown](https://mialdeatdo.com/wp-content/uploads/2022/03/10-2.jpg)
#
# ---
# # formula para calcular el area
# $ A = b * h/ 2$
# ---
# # datos de entrada
# $h$?
# $b$?
#
#
# ---
# # diagrama de flijo en lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/a25308051280060-pixel/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes-/refs/heads/main/DF%20area%20triangulo.png)

# %%
# calcular area de un triangulo
# variables b, h, A
# formulas A = b * h / 2
# calcular el valor de b
# calcular el valor de h
print("calcular el area de un triangulo")
b = float(input("ingrese el valor de la base: "))
h = float(input("ingrese el valor de la altura: "))
A = b * h / 2
print("el area del triangulo es: ", A)
print(" Ambar Fierro NL = 19")
# Out:
# calcular el area de un triangulo
# ingrese el valor de la base: 5
# ingrese el valor de la altura: 5
# el area del triangulo es:  12.5
#  Ambar Fierro NL = 19

# %% [markdown]
# ## relacion entre codigo y DF tldraw
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/a25308051280060-pixel/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes-/refs/heads/main/tldraw%20DF%20triangulo%201.png)
