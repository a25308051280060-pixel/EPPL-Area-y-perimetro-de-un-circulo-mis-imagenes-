# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280060-pixel/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes-/blob/main/El_profe_circulo_Ambar_Fierro_0060.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ambar Fierro NL = 19  Fecha 25/Mar/2026 ❤
# ---
# # Calcular Area y perimetro de un circulo
# ---
#
# ![Logo de Markdown](https://raw.githubusercontent.com/a25308051280060-pixel/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes-/refs/heads/main/circulo_area_de_perimetro.PNG)
#
# ---
#
# ## formula para calcular el circuloo
# $A = \pi*r^2$
# ---
# #formula para calcular perimetro
# $ = 2\pi*r$
#
# ---
#
# ## datos de entrada
# $r$ ?
# ---
# ## diagrama de flujo en LucidChart
# ![Logo de Markdown](https://raw.githubusercontent.com/a25308051280060-pixel/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes-/refs/heads/main/DF%20area%20circulo.png)

# %%
# calcular area y perimetro de un circulo
# variables A,P,r
#formulas A = pi*r^2 y P = 2 * pi * r
# calcular el valor de r
import math
print("calcular area y perimetro de un circulo")
r = float(input("ingrese el valor del radio: "))
A = math.pi*r**2
P = 2*math.pi*r
print("el area del circulo es: ", A)
print("el perimetro del circulo es: ", P)
print("Ambar Fierro NL=19")
# Out:
# calcular area y perimetro de un circulo
# ingrese el valor del radio: 5
# el area del circulo es:  78.53981633974483
# el perimetro del circulo es:  31.41592653589793
# Ambar Fierro NL=19

# %% [markdown]
# # relacion entre codigo y DF Tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/a25308051280060-pixel/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes-/refs/heads/main/tldraw%20DF%20y%20codigo%20(1).png)
